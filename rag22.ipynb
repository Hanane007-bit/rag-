# %%
import json
import tiktoken

#import pandas as pd

from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_community.document_loaders import PyPDFDirectoryLoader, PyPDFLoader
from langchain_community.vectorstores import Chroma

from dotenv.ipython import load_dotenv
import os

# %%
load_dotenv(override=True)
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)

# %%
pdf_file = "./pdfs/Rapport Financier Annuel  OCP 2023.pdf"

# %%
pdf_loader = PyPDFLoader(pdf_file)

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader
loader = PyPDFDirectoryLoader(path = "./pdfs")

# %%
# Option 1: no tiktoken-specific encoding; this works independent of tiktoken version
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=20
)

# Option 2: if you want to keep .from_tiktoken_encoder, choose an encoding available in tiktoken 0.12.0
# text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
#     encoding_name='p50k_base',
#     chunk_size=300,
#     chunk_overlap=20
# )

# %%
chunks = loader.load_and_split(text_splitter)

# %%
len(chunks)
# Out:
# 1970

# %%
from langchain_openai import OpenAIEmbeddings
embedding_model = OpenAIEmbeddings(model='text-embedding-ada-002')

# %%
import tiktoken
tiktoken.get_encoding("cl100k_base")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 import tiktoken
# ----> 2 tiktoken.get_encoding("cl100k_base")
#
# File ~/Documents/rag/.venv/lib/python3.11/site-packages/tiktoken/registry.py:79, in get_encoding(encoding_name)
#
# ValueError: Unknown encoding cl100k_base.
# Plugins found: []
# tiktoken version: 0.12.0 (are you on latest?)

# %%
vectorstore = Chroma.from_documents(
    chunks,
    embedding_model,
    collection_name="rapport_ocp_V2",
    persist_directory="./store"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 vectorstore = Chroma.from_documents(
#       2     chunks,
#       3     embedding_model,
#       4     collection_name="rapport_ocp_V2",
#       5     persist_directory="./store"
#       6 )
#
# File ~/Documents/rag/.venv/lib/python3.11/site-packages/langchain_community/vectorstores/chroma.py:887, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885 texts = [doc.page_content for doc in documents]
#     886 metadatas = [doc.metadata for doc in documents]
# --> 887 return cls.from_texts(
#     888     texts=texts,
#     889     embedding=embedding,
#     890     metadatas=metadatas,
#     891     ids=ids,
#     892     collection_name=collection_name,
# ...
